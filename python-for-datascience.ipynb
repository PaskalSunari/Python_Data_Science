# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# **Variables**

# %%
x = 3
print(type(x))

# %%
# %whos

# %%
x = 5.7
# %whos
print(type(x))

# %%
a = 5.32
# %whos
print(type(a))

# %%
a,b,c,d,e = 3,4,5,6,7
# %whos

# %%
del x
# %whos

# %%
print(x)

# %%
x = 2 +4j
# %whos
print(type(x))

# %%
name = "What is your name"
# %whos
print(type(name))

# %% [markdown]
# **Operators**

# %%
# %whos

# %%
sumOfaAndb = a + b
print(type(sumOfaAndb))
# %whos

# %%
op = ((sumOfaAndb)**2)/7
print(op)
# %whos

# %%
s1 = "hello"
s2 = "World"
s = s1 + s2
print(s)
# %whos

# %%
print(7//3) # Returns the Quotient
print(7/3)  # Returns Division

# %%
_ #is used in the interactive interpreter to store the result of the last evaluation
_/2

# %% [markdown]
# **Boolean**

# %%
a = True
b = True
c = False
# %whos

# %%
print(a and b)
print(a and c)
print(c and a)

# %%
print(a or b)
print(a or c)
print(c or a)
print(c or c)

# %%
not a

# %%
not(a and b) or not(a or b)

# %% [markdown]
# **Comparisions**

# %%
c = 2<3
print(type(c))
print(c)

# %%
d = 3 == 3.0
print(d)

# %%
3 == 3.0

# %%
x = 4
y = 9
z = 8.3
r = -3

# %%
(x < y) and (z < y) or (r == x)

# %%
(True or False) and False

# %%
print((not(2!=3) and True) or (False and True))

# %%
print(round(4.385))

# %%
print(round(4.586))

# %%
print(round(40.356987,3))

# %%
# %whos

# %%
b = divmod(27, 5)
print(b)

# %%
print(type(b))

# %%
type(b)

# %%
b[0]

# %%
b[1]

# %%
34//9

# %%
34/9

# %%
34%9

# %%
isinstance(3, int)

# %%
isinstance(3.4, (float, int))

# %%
isinstance(3 + 2j, (int, float, str, complex))

# %%
pow(2,4)

# %%
2**4

# %%
pow(2,4,7)

# %%
x = input("Enter a number: ")

# %%
type(x)

# %%
x = int(x)

# %%
type(x)

# %%
x + 20

# %%
a = float(input("Enter a real number: "))

# %%
type(a)

# %%
b = float(input("Enter a number: "))

# %%
help(pow)

# %%
pow(2,4,7)

# %%
help(input)

# %%
a = input("Enter the number: ")
b = input("Eneter another number: ")

if a < b:
    print(a)
    print("I am still in the condition.")
print("I am outside of the condition")

# %%
a = int(input())
b = int(input())
if a>b:
    print(a)
    print("I am still inside if condition")
print("I am outside the if condition")

# %%
a = input("Enter the real number: ")
b = input("Enter the another number: ")
if a < b:
    print(a)
    print("inside if condition")
else:
    print(b)
    print("The end of else statement")

# %%
a = 40
b = 30
if a == b:
    print("Equal")
elif a > b:
    print("A")
else:
    print("B")

# %%
a = int(input("Enter the number: "))
if a >= 85:
    print("grade: A+")
elif a < 85 and a >= 70:
    print("grade: A-")
elif a < 70 and a >= 65:
    print("grade: B")
elif a < 65 and a >=60:
    print("grade: B-")
else:
    print("below average")

# %%
a = int(input("Enter any integer digit: "))
if a > 10:
    print("Inside the top if")
    if a > 20:
        print("inside nested if")
    else:
        print("number is <= 20")
else:
    print("number is <=10")
print("outside of all if statements")

# %%
n = int(input())
i = 1
while i < n:
    print(i**n)
    print("This is the iteration Number: ", i)
    i = i+1
print("loop is done")

# %%
n = 10
i = 1
while True:
    if i%9 == 0:
        print("inside if ")
        break
    else:
        print("inside else ")
        i = i+1
print("outside the loop")

# %%
n = 10
i = 1
while True:
    if i%9 != 0:
        print("inside if")
        i = i+1
        continue
    print("something")
    print("something else")
    break
print("YOu have done it")

# %%
9%9 != 0

# %%
help(range)

# %%
L = []
for i in range(1, 20, 3):
    print(i)
    L.append(i**2)
print(L)

# %%
S = {"apple", 4.9, "cherry"}
i = 1
for x in S:
    print(x)
    i+=1
    if i == 3:
        break
    else:
        print("Loop terminates with success")
print("outside the loop")

# %%
4.9 == 4.9

# %%
D = {"A": 4, "B": -9, "C": "abc"}
for x in D:
    print(x, D[x])

# %%
S = {"apple", 4.9, "cherry"}
i = 1
for x in S:
    print(x)
    i = i+1
    if i == 3:
        break
    else:
        pass
else:
    print("Loop terminates with success")
print("outside of the loop")

# %%
""" Given a list of numbers i.e. [1,2,4,-5,7,9,3,2], make another list
that contains all the items in sorted order from min to max. i.e. your 
result will be another list like [-5,1,2,2,3,7,9]
"""
L = [1,2,4,-5,7,9,3,2]
for j in range(len(L)):
    m = L[j]
    idx = j
    c = j
    for i in range(j, len(L)):
        if L[i]<m:
            m = L[i]
            idx = c
        c = c+1
    tmp = L[j]
    L[j] = m
    L[idx] = tmp
print(L)

# %%
help(range)

# %%
def printsuccess():
    print("I am done")
    print("Send me another task")
printsuccess()

# %%
def printsuccess1():
    """This function is printing the message the is passed in it"""
    print("hello world")

# %%
help(printsuccess1)

# %%
def printMsg(msg):
    """
    The function prints the message supplied by the user
    or prints that msg is not in the form of string
    """
    if isinstance(msg, str):
        print(msg)
    else:
        print("Your input argument is not a string")
        print("her is the type of argument that you passed", type(msg))

# %%
help(printMsg)

# %%
help(isinstance)

# %%
printMsg?

# %%
y = "hellow there"
printMsg(y)

# %%
def mypow(a, b):
    c = a**b
    print(c)

# %%
mypow(2,3)

# %%
mypow?

# %%
def checkArgs(a,b,c):
    if isinstance(a,(int,float)) and isinstance(b,(int,float)) and isinstance(c,(int,float)):
        print((a+b+c)**2)
    else:
        print("The arguments are false")

# %%
checkArgs(2,3,4)

# %%
checkArgs(2,3,"g")

# %%
def f(a,b,c):
    print("a is :", a)
    print("b is : ", b)
    print("c is : ", c)

# %%
f("paskal", "game", 25)

# %%
def r():
    a = 5
    b = 6
    c = "paskal"
    return a,b,c

# %%
x,y,z = r()
print(x,y,z)

# %%
# def myAddUniversal(*args):
#     s = 0
#     for i in range(len(args)):
#         s += args[i] # s = s+args[i]
#     return s
def myUniversal(*args):
    s = 0
    for i in range(len(args)):
        s = s+args[i]
    return s

# %%
print(myUniversal(1,2,3,1,2,3))

# %%
def printAllVariablesNamesAndValues(**args):
    for x in args:
        print("Variable name is :", x, "And value is :", args[x])
printAllVariablesNamesAndValues(a = 3,b="B",c="CCC",y=6.7)

# %%
""" Given a list of numbers i.e. [1,2,4,-5,7,9,3,2], make another list
that contains all the items in sorted order from min to max. i.e. your 
result will be another list like [-5,1,2,2,3,7,9]
"""
# def findMin(L,startIndx):
#     m = L[startIndx]
#     idx = startIndx    
#     for i in range(startIndx,len(L)):
#         x = L[i]
#         if x<m:
#             m = x
#             idx = i
#         else:
#             pass                
#     return m,idx

def findMin(L, startIndx):
    m = L[startIndx]
    idx = startIndex
    for i in range(startIndx, len(L)):
        x = L[i]
        if x<m:
            m = x
            idx = i
        else:
            pass
    return m, idx

# %%
def swapValues(L, idx1, idx2):
    tmp = L[idx1]
    L[idx1] = L[idx2]
    L[idx2] = tmp
    return L

# %%
L = [2,3,6,7]
L2 = swapValues(L,1,3)
print(L2)

# %%
L2 = sortList([2,1,5,3,-8,17])
print(L2)

# %%
checkIfNotNumeric?

# %%
a = """This is first line
This is second line
This is last line"""
print(a)

# %%
s = "how are you and how are you"
print(s[5])

# %%
print(s[3])

# %%
s[0:10]

# %%
s[-1]

# %%
s[-3]

# %%
# %whos

# %%
s[-12:-3]

# %%
#s[start:end:step]
s[0:12:2]

# %%
s[:12]

# %%
s[3:]

# %%
s[::-1]

# %%
s

# %%
help(strip)

# %%
a = "abc;def;ghi;jkl"
a.split(";")

# %%
a.capitalize()

# %%
a.upper()

# %%
a.islower()

# %%
print("we are learnint \"string\" here")

# %%
print("we are on the \t tab line")

# %%
print("c:\name\drive")

# %% [markdown]
# **R-String for file path**

# %%
print(r"c:\name\drive")

# %% [markdown]
# **Data Structures**

# %%
L = [1,3,4.9,"name",3]
T = (1,3,4.9,"name",3)
S = {1,3,4.9,"name",3}
D = {23:"twothree",'B':43,'C':'CCD'}

# %%
print("the type of L is: ", type(L))
print("The type of T is: ", type(T))
print("The type of S is: ", type(S))
print("The type of D is: ", type(D))

# %%
print(L[1])
print(T[1])
print(3 in S)
print(D['B'])
print(D[23])

# %%
L

# %%
# %whos

# %%
L[1:4]

# %%
L[::-1]

# %%
T[:3]

# %%
T

# %%
L = L + ["how", "are", 6, "you"]

# %%
L

# %%
L.append(6.8)

# %%
L

# %%
T2 = ("a", "b", 45)
T3 = T + T2

# %%
T3

# %%
S

# %%
S.add(45)

# %%
S

# %%
S.update({"paskal", 23, 1})

# %%
S

# %%
D

# %%
D["newkey"] = "newvalue"

# %%
D

# %%
D2 = {"y": "yy", "Z": 2.3}

# %%
L

# %%
del(L[3])

# %%
L

# %%
S

# %%
S.remove("name")

# %%
S

# %%
D

# %%
del D["C"]

# %%
D

# %%
D = D + D2

# %%
D.update(D2)

# %%
D

# %%
L

# %%
L2 = L

# %%
L2

# %%
L2[2] = "Four point nine"

# %%
L2

# %%
L

# %%
L2 = L.copy()

# %%
L2

# %%
L2[2] = 4.9

# %%
L2

# %%
L

# %%
L3 = L[1:5]

# %%
L3

# %%
L3[0] = "Three"

# %%
L3

# %%
L

# %%
help(L.append)

# %%
L.clear?

# %%
L.pop?

# %%
L.reverse?

# %%
L

# %%
L[::-1]

# %%
D.items()

# %%
L

# %%
T

# %%
S

# %%
D

# %%
D2 = {'A': L, 'B': T, 'C': S, 'D': D}

# %%
D2['A'][3]

# %%
# %whos

# %%
k = D2['D']

# %%
k

# %%
for x in k:
    print(x, k[x])

# %%
L3 = [L,T,D,"game",23]

# %%
type(L3)

# %%
L3

# %%
type(L3[2])

# %%
L3 = [x**2 for x in range(10)]

# %%
L3

# %%
S3 = {x**2 for x in range(1,20,3)}

# %%
S3

# %%
D

# %%
23 in D

# %%
43 in D

# %%
'B' in D

# %%
"""
Let say you are a teacher and you have different student
records containing id of a student and the marks list in each subject
where different students have taken different number of subjects. All
these records are in hard copy. You want to enter all the data in computer
and want to compute the average marks of each student and display
"""

def getDataFromUser():
    D = {}
    while True:
        studentId = input("Enter the student ID: ")
        marksList = input("Enter marks by comma separated values: ")
        moreStudent = input("Enter 'no' to quit insertion: ")
        if studentId in D:
            print(studentId, "is already inserted")
        else:
            D[studentId] = marksList.split(",")
        if moreStudent.lower() == "no":
            return D

# %%
studentData = getDataFromUser()

# %%
studentData

# %%
def getAvgMarks(D):
    avgMarks = {}
    for x in D:
        L = D[x]
        s = 0
        for marks in L:
            s = s + int(marks)
        avgMarks[x] = s/len(L)
    return avgMarks

# %%
avgM = getAvgMarks(studentData)

# %%
avgM

# %%
import numpy as np

# %%
a = np.array([1,2,3,5,7],dtype='i')
b = np.array((2,3,5),dtype='f')

# %%
print(a)

# %%
type(a)

# %%
type(b)

# %%
a.dtype

# %%
b.dtype

# %%
a = np.array([[1,2,3],[4,5,6]])

# %%
a.ndim

# %%
a[0,2]

# %%
B = np.array([[1,2,3,-1],[2,4,5,9]])

# %%
B.ndim

# %%
B[1,2]

# %%
C = np.array([[[1,2,3],[4,5,6],[0,0,-1]],[[-1,-2,-3],[-4,-5,-6],[0,0,1]]])

# %%
C.shape[2]

# %%
C[1,0,2]

# %%
type(C)

# %%
A = np.array([2])

# %%
A.ndim

# %%
B = np.array(3)

# %%
B.ndim

# %%
type(C)

# %%
C.size

# %%
C.nbytes

# %%
A =np.arange(20,100,3)

# %%
print(A)

# %%
print(range(10))

# %%
print(list(range(10)))

# %%
# %whos

# %%
print(A)

# %%
A = np.random.permutation(np.arange(10))

# %%
print(A)

# %%
np.random.randint?

# %%
v = np.random.randint(20,300)
print(v)

# %%
type(v)

# %%
A = np.random.rand(100)

# %%
import matplotlib.pyplot as plt
plt.hist(A, bins=100)

# %%
B = np.random.rand(10000)
plt.hist(B, bins=200)

# %%
import matplotlib.pyplot as plt
import pandas as pd
B = np.random.randn(100000)
plt.hist(B, bins=200)

# %%
C = np.random.rand(2,3)
C

# %%
C.ndim

# %%
C  = np.random.rand(2,3,4,2)

# %%
C

# %%
C.ndim

# %%
D = np.arange(100).reshape(4,25)

# %%
D

# %%
D.ndim

# %%
D.shape

# %%
D = np.arange(100).reshape(4,5,5)

# %%
D.shape

# %%
np.zeros?

# %%
np.ones?

# %%
A = np.arange(100)

# %%
b = A[3:10]
print(b)

# %%
b[0] = -12000

# %%
print(b)

# %%
A

# %%
A[::3]

# %%
A[::-5]

# %%
A[::-1]

# %%
idx = np.argwhere(A==-12000)[0][0]

# %%
idx

# %%
A[idx] = 3

# %%
A

# %%
A = np.around(10*np.random.rand(5,4))

# %%
A

# %%
np.random.rand?

# %%
A[1,2]

# %%
A

# %%
A[1,:]

# %%
A[:,1]

# %%
A[1:3,2:4]

# %%
A

# %%
A.T

# %%
import numpy.linalg as lg

# %%
lg.inv(np.random.rand(3,3))

# %%
A

# %%
A.sort(axis=0)

# %%
A

# %%
A.sort(axis=1)

# %%
A

# %%
A = np.arange(100)

# %%
A

# %%
B = A[[3,5,6]]

# %%
B

# %%
B[0] = -4

# %%
B

# %%
B

# %%
B = A[A<40]

# %%
B

# %%
# &, and 
# |, or
# ~, not
B = A[(A<40) & (A>30)]

# %%
B

# %%
A = np.round(10*np.random.rand(2,3))

# %%
A

# %%
A+3

# %%
A+(np.arange(2).reshape(2,1))

# %%
A

# %%
B = np.round(10*np.random.rand(2,2))

# %%
B

# %%
C = np.hstack((A,B))

# %%
C

# %%
A = np.random.permutation(np.arange(10))

# %%
A

# %%
A.sort()

# %%
A

# %%
np.sort(A)

# %%
A = A[::-1]
A

# %%
A = np.array(["abc",'howare you','u765','13er'])

# %%
A.sort()

# %%
A

# %%
B = np.random.rand(1000000)
# %timeit sum(B)
# %timeit np.sum(B)

# %%
def mySum(G):
    s = 0
    for x in G:
        s+=x
        return s

# %%
import pandas as pd
print(pd.__version__)

# %%
A = pd.Series([2,3,4,5],index=['a','b','c','d'])

# %%
type(A.values)

# %%
type(A)

# %%
A.index

# %%
A

# %%
A['a':'c']

# %%
grads_dict = {'A':4,'B':3.5,'C':3,'D':2.5}
grads = pd.Series(grads_dict)

# %%
grads.values

# %%
marks_dict = {'A':85,'B':75,'C':65,'D':55}
marks = pd.Series(marks_dict)

# %%
marks

# %%
marks['A']

# %%
marks[0:2]

# %%
grads

# %%
D = pd.DataFrame({'Marks':marks, 'Grades':grads})

# %%
D

# %%
D.T

# %%
D

# %%
D.values

# %%
D.values[2,0]

# %%
D.columns

# %%
D['scaledMarks'] = 100*(D['Marks']/90)

# %%
D

# %%
del D['scaledMarks']

# %%
D

# %%
G = D[D['Marks']>70]

# %%
G

# %%
A = pd.DataFrame([{'a':1,'b':4},{'b':-3,'c':9}])

# %%
A

# %%
A.fillna(0)

# %%
A.dropna?

# %%
A = pd.Series(['a','b','c'],index=[1,3,5])

# %%
A[1]

# %%
A[3]

# %%
A[1:3]

# %%
A.loc[1:3]

# %%
A.iloc[1:3]

# %%
A

# %%
from sklearn.impute import SimpleImputer
import pandas as pd

# %%
df = pd.read_csv('../input/corona-virus-report/covid_19_clean_complete.csv')

# %%
df.head(5)

# %%
df.drop(['WHO Region'], axis=1, inplace=True)

# %%
df.head(5)

# %%
df = pd.read_csv('../input/corona-virus-report/full_grouped.csv')

# %%
df.head(5)

# %%
df.rename(columns={'Country/Region':'Country'}, inplace=True)

# %%
df.head()

# %%
df.describe()

# %%
df.info()

# %%
df = df.fillna('NA')

# %%
df.info()

# %%
df.head()

# %%
df2 = df.groupby('Country')[['Country','Confirmed', 'Deaths','Recovered']].sum().reset_index()

# %%
df2.head()

# %%
df2 = df.groupby(['Country','Date'])[['Country','Date','Confirmed', 'Deaths','Recovered']].sum().reset_index()

# %%
df2.head()

# %%
df3 = df2[df2['Confirmed']>100]

# %%
df3.head()

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,10,1000)
y = np.sin(x)
plt.plot(x,y)

# %%
plt.scatter(x[::10],y[::10], color='red')

# %%
plt.plot(x,y,color='b')
plt.plot(x,np.cos(x),color='g')

# %%
'''
Part3: trend Analysis
'''

# %% [markdown]
# **Part 3: Trend Analysis**

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer

# %%
df = pd.read_csv('../input/novel-corona-virus-2019-dataset/covid_19_data.csv')

# %%
df.head()

# %%
df.drop(['SNo', 'Last Update'], axis=1, inplace=True)
df.rename(columns={'ObservationDate':'Date','Province/State':'State','Country/Region':'Country'},inplace=True)

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
imputer = SimpleImputer(strategy="constant")
df2 = pd.DataFrame(imputer.fit_transform(df),columns=df.columns)

# %%
df2.head()

# %%
df2.head()

# %%
df3 = df2.groupby(['Date'])[['Date','Confirmed','Deaths','Recovered']].sum().reset_index()

# %%
df3.head(5)

# %%
countries = df2['Country'].unique()

# %%
len(countries)

# %%
# for idx in range(0,len(countries)):    
#     C = df3[df3['Country']==countries[idx]].reset_index()        
#     plt.scatter(np.arange(0,len(C)),C['Confirmed'],color='blue',label='Confirmed')
#     plt.scatter(np.arange(0,len(C)),C['Recovered'],color='green',label='Recovered')
#     plt.scatter(np.arange(0,len(C)),C['Deaths'],color='red',label='Deaths')
#     plt.title(countries[idx])
#     plt.xlabel('Days since the first suspect')
#     plt.ylabel('Number of cases')
#     plt.legend()
#     plt.show() 
for idx in range(0, len(countries)):
    C = df2[df2['Country']==countries[idx]].reset_index()
    plt.scatter(np.arange(0,len(C)),C['Confirmed'],color='blue',label='Confirmed')
    plt.scatter(np.arange(0,len(C)),C['Recovered'],color='green',label='Recovered')
    plt.scatter(np.arange(0,len(C)),C['Deaths'],color='red',label='Deaths')
    plt.title(countries[idx])
    plt.xlabel('Days since the first suspect')
    plt.ylabel('Number of cases')
    plt.legend()
    plt.show()

# %%
df3 = df2.groupby(['Date'])[['Date','Confirmed','Deaths','Recovered']].sum().reset_index()

# %%
C = df3
plt.scatter(np.arange(0,len(C)), C['Confirmed'],color='blue',label='Confirmed')
plt.scatter(np.arange(0,len(C)), C['Recovered'], color='green', label='Recovered')
plt.scatter(np.arange(0,len(C)), C['Deaths'],color='Red',label='Deaths')
plt.title('World')
plt.xlabel('Days since the first suspect')
plt.ylabel('Number of cases')
plt.legend()
plt.show()
